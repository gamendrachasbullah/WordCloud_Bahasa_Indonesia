# %%
#Install pyDrive untuk mengakses file yang ada di direktori Google Drive
# !pip install pyDrive

# %%
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
def word_count(str):
  counts = dict()
  words = str.split()

  for word in words:
    if word in counts:
      counts[word] += 1
    else:
      counts[word] = 1

  return counts

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#Sesuaikan id dengan id yang Anda miliki di direktorinya masing-masing.
download = drive.CreateFile({'id': '1stdJAPwMT3JNgfEH9Po3ayVBVBT3CYPe'})

# %%
text = download.GetContentFile("lagu.txt")

# %%
text
# Out:
# 'Indonesia Raya\nCipt: Wage Rudolf Soepratman\n\nI\nIndonesia tanah airku\nTanah tumpah darahku\nDi sanalah aku berdiri\nJadi pandu ibuku\nIndonesia kebangsaanku\nBangsa dan tanah airku\nMarilah kita berseru\nIndonesia bersatu\nHiduplah tanahku\nHiduplah negriku\nBangsaku Rakyatku Semuanya\nBangunlah jiwanya\nBangunlah badannya\nUntuk Indonesia Raya\n(Ulangan)\nIndonesia Raya\n"Merdeka, Merdeka"\n"Tanahku, Negriku yang kucinta"\nIndonesia Raya\n"Merdeka, merdeka"\nHiduplah Indonesia Raya\n\nII\n"Indonesia, tanah yang mulia"\nTanah kita yang kaya\nDisanalah aku berdiri\nUntuk slama-lamanya\n"Indonesia, tanah pusaka"\nP’saka kita semuanya\nMarilah kita mendoa\nIndonesia bahagia\nSuburlah tanahnya\nSuburlah jiwanya\n"Bangsanya, Rakyatnya, Semuanya"\nSadarlah hatinya\nSadarlah budinya\nUntuk Indonesia Raya\n(Ulangan)\nIndonesia Raya\n"Merdeka, Merdeka"\n"Tanahku, Negriku yang kucinta"\nIndonesia Raya\n"Merdeka, merdeka"\nHiduplah Indonesia Raya\n\nIII\n"Indonesia, tanah yang suci"\nTanah
# ...

# %%
a = word_count(text)
a
# Out:
# {'"Bangsanya,': 1,
#  '"Indonesia,': 4,
#  '"Merdeka,': 6,
#  '"Pulaunya,': 1,
#  '"Tanahku,': 3,
#  '(Ulangan)': 3,
#  'Bangsa': 1,
#  'Bangsaku': 1,
#  'Bangunlah': 2,
#  'Cipt:': 1,
#  'Di': 2,
#  'Disanalah': 1,
#  'Hiduplah': 5,
#  'I': 1,
#  'II': 1,
#  'III': 1,
#  'Indonesia': 18,
#  'Jadi': 1,
#  'Lautnya,': 1,
#  'Majulah': 2,
#  'Marilah': 3,
#  'Merdeka"': 3,
#  'M’njaga': 1,
#  'Negriku': 3,
#  'P’saka': 1,
#  'Rakyatku': 1,
#  'Rakyatnya,': 1,
#  'Raya': 13,
#  'Rudolf': 1,
#  'Sadarlah': 2,
#  'Semuanya': 1,
#  'Semuanya"': 2,
#  'Soepratman': 1,
#  'Suburlah': 2,
#  'S’lamatlah': 2,
#  'Tanah': 4,
#  'Untuk': 4,
#  'Wage': 1,
#  'abadi': 1,
#  'airku': 2,
#  'aku': 4,
#  'badannya': 1,
#  'bahagia': 1,
#  'berdiri': 3,
#  'berjanji': 1,
#  'bersatu': 1,
#  'berseri"': 1,
#  'berseru': 1,
#  'budinya': 1,
#  'dan': 1,
#  'darahku': 1,
#  'hatinya': 1,
#  'ibu': 1,
#  'ibuku': 1,
#  'jiwanya': 2,
#  'kaya': 1,
#  'kebangsaanku': 1,
#  'kita': 6,
#  'kucinta"': 3,
# ...

# %%
pyplot.bar(range(len(a)),list(a.values()),align="center")
pyplot.xticks(range(len(a)), list(a.keys()))
pyplot.xticks(rotation=90)
pyplot.savefig("Text Occurance.png")
pyplot.show()

# %%
from matplotlib import pyplot
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(background_color='white').generate(text)

# %%
pyplot.clf()
pyplot.imshow(wordcloud)
pyplot.axis('off')
pyplot.savefig("indonesia-raya.png",dpi = (300))
pyplot.show()

# %%
import numpy
from PIL import Image

# %%
#Sesuaikan id dengan id yang Anda miliki di direktorinya masing-masing
download = drive.CreateFile({'id': '1oVKPRQav-eOOFAown9LTewNcuxooomgd'})
img = download.GetContentFile("indonesia.png","image/png")

# %%
mask = numpy.array(Image.open("indonesia.png"))

# %%
Image.open("indonesia.png")

# %%
wordcloud = WordCloud(width=600,height=400,background_color="white",mask=mask).generate(text)

# %%
pyplot.clf()
pyplot.imshow(wordcloud)
pyplot.axis('off')
pyplot.savefig("indonesia-raya-masked.png",dpi = (300))
pyplot.show()
